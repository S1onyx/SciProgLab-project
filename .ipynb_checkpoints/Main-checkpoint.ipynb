# %%
pip install scipy matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Kapitel 0: Einleitung und Überblick

# %% [markdown]
# # Kapitel 1: Riemann-Integrale mit Ober- und Untersummen, Trapezregel

# %%
from typing import Callable, Tuple
from scipy.optimize import minimize_scalar

def find_extrema(func: Callable[[float], float], a: float, b: float) -> Tuple[float, float]:
    """
    Findet das Minimum und Maximum der Funktion func im Intervall [a, b].
    
    Gibt ein Tupel (f_min, f_max) zurück.
    """
    if a >= b:
        raise ValueError("Ungültiges Intervall: a muss kleiner als b sein.")
    
    # Minimum berechnen
    result_min = minimize_scalar(func, bounds=(a, b), method='bounded')
    if not result_min.success:
        raise ValueError("Minimum konnte nicht gefunden werden.")
    f_min = result_min.fun

    # Maximum berechnen (über -f(x))
    result_max = minimize_scalar(lambda x: -func(x), bounds=(a, b), method='bounded')
    if not result_max.success:
        raise ValueError("Maximum konnte nicht gefunden werden.")
    f_max = -result_max.fun

    return f_min, f_max

# %%
from typing import Callable, Tuple
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.optimize import minimize_scalar

def sicher_auswerten(f: Callable[[float], float], x: float) -> float:
    """Führt eine sichere Auswertung der Funktion f an der Stelle x durch."""
    try:
        y = f(x)
        if not math.isfinite(y):
            raise ValueError(f"f({x}) = {y} ist kein endlicher Wert (NaN oder ∞).")
        return y
    except ZeroDivisionError:
        raise ValueError(f"f({x}): Division durch Null.")
    except ValueError as ve:
        raise ValueError(f"f({x}): Ungültiger mathematischer Ausdruck – z. B. Wurzel aus negativer Zahl oder log(≤0): {ve}")
    except Exception as e:
        raise ValueError(f"f({x}): Allgemeiner Fehler bei der Funktionsauswertung: {e}")

def vektorisiere(f: Callable[[float], float]) -> Callable[[np.ndarray], np.ndarray]:
    """Wandelt eine skalare Funktion in eine NumPy-kompatible vektorisierte Funktion um."""
    return np.vectorize(lambda x: sicher_auswerten(f, x))

def numerische_integration(
    f: Callable[[float], float],
    a: float,
    b: float,
    n: int,
    methode: str,
    zeige_plot: bool = True
) -> float:
    if n <= 0:
        raise ValueError("Die Anzahl der Unterteilungen (n) muss größer als 0 sein.")
    if a >= b:
        raise ValueError("Ungültiges Intervall: a muss kleiner als b sein.")
    if not callable(f):
        raise ValueError("Ungültiges Argument: f muss eine aufrufbare Funktion sein.")

    deltaX = (b - a) / n
    x_i = np.linspace(a, b, n + 1)
    f_vec = vektorisiere(f)
    summe = 0.0

    try:
        if methode == "Untersumme":
            for i in range(n):
                f_min, _ = find_extrema(f, x_i[i], x_i[i+1])
                summe += f_min * deltaX

        elif methode == "Obersumme":
            for i in range(n):
                _, f_max = find_extrema(f, x_i[i], x_i[i+1])
                summe += f_max * deltaX

        elif methode == "Trapezregel":
            y_i = f_vec(x_i)
            summe = deltaX * (np.sum(y_i) - 0.5 * (y_i[0] + y_i[-1]))

        else:
            raise ValueError('Ungültige Methode: Erlaubt sind "Untersumme", "Obersumme" oder "Trapezregel".')

    except Exception as fehler:
        raise fehler

    if zeige_plot:
        try:
            xs = np.linspace(a, b, 1000)
            ys = f_vec(xs)
            fig, ax = plt.subplots(figsize=(8, 5))
            ax.plot(xs, ys, label="f(x)", color="black", linewidth=1.5)
            ax.axhline(0, color="gray", linestyle="--")

            label_gesetzt = False
            if methode == "Untersumme":
                for i in range(n):
                    f_min, _ = find_extrema(f, x_i[i], x_i[i+1])
                    ax.bar(x_i[i] + deltaX / 2, f_min, width=deltaX, align='center',
                           edgecolor='blue', color='blue', alpha=0.4,
                           label='Untersumme' if not label_gesetzt else "")
                    label_gesetzt = True

            elif methode == "Obersumme":
                for i in range(n):
                    _, f_max = find_extrema(f, x_i[i], x_i[i+1])
                    ax.bar(x_i[i] + deltaX / 2, f_max, width=deltaX, align='center',
                           edgecolor='red', color='red', alpha=0.4,
                           label='Obersumme' if not label_gesetzt else "")
                    label_gesetzt = True

            elif methode == "Trapezregel":
                y_i = f_vec(x_i)
                for i in range(n):
                    ax.fill([x_i[i], x_i[i], x_i[i+1], x_i[i+1]],
                            [0, y_i[i], y_i[i+1], 0],
                            color='green', alpha=0.3,
                            label='Trapezregel' if not label_gesetzt else "")
                    label_gesetzt = True

            ax.set_title(f"Numerische Integration mittels {methode}\n"
                         f"Ergebnis bei n={n} | ≈ {round(summe, 5)}")
            ax.set_xlabel("x")
            ax.set_ylabel("y")
            ax.legend()
            ax.grid(True)
            plt.tight_layout()
            plt.show()

        except Exception as err:
            print(f"Warnung beim Zeichnen der Funktion: {err}")

    return round(summe, 3)

# %%
#Beispiele
ergebnis_unter = numerische_integration(lambda x: x**2, a=0, b=2, n=10, methode="Untersumme")
print("Untersumme Ergebnis:", ergebnis_unter)
ergebnis_ober = numerische_integration(lambda x: x**2, a=0, b=2, n=10, methode="Obersumme")
print("Obersumme Ergebnis:", ergebnis_ober)
ergebnis_trapez = numerische_integration(lambda x: x**2, a=0, b=2, n=10, methode="Trapezregel")
print("Trapezregel Ergebnis:", ergebnis_trapez)
# Out:
# Untersumme Ergebnis: 2.28
# Obersumme Ergebnis: 3.08
# Trapezregel Ergebnis: 2.68

# %% [markdown]
# # Kapitel 2: Monte-Carlo-Integration

# %% [markdown]
# Die Monte-Carlo-Integration ist ein numerisches Verfahren zur Berechnung von Integralen, das auf der Verwendung von Zufallszahlen basiert. Sie wird besonders dann eingesetzt, wenn klassische Methoden (wie Trapezregel oder Simpsonregel) aufgrund hoher Dimensionalität oder komplexer Integrationsbereiche nicht praktikabel sind.
#
# Für ein eindimensionales Integral nutzt man n Zufallszahlen aus dem Intervall [a, b].
#
# Für eine explorative Methode benötigt man zusätzlich eine Schätzung der minimalen und maximalen Funktionswerte.

# %%
import numpy as np
import matplotlib.pyplot as plt

def monte_carlo_integration(func, a, b, n_punkte=10000, zeige_plot=True,
                            explorativ=True, y_unter=None, y_ober=None):
    if a >= b:
        raise ValueError("Untere Grenze a muss kleiner als obere Grenze b sein.")

    # Automatische oder manuelle y-Grenzen
    if explorativ:
        f_min, f_max = find_extrema(func, a, b)
        if not np.isfinite(f_min) or not np.isfinite(f_max):
            raise ValueError("Funktion liefert ungültige Extremwerte.")
        y_unter = min(f_min, 0)
        y_ober = max(f_max, 0)
    else:
        if y_unter is None or y_ober is None:
            raise ValueError("Bei explorativ=False müssen y_unter und y_ober angegeben werden.")
        if y_unter >= y_ober:
            raise ValueError("y_unter muss kleiner als y_ober sein.")

    if y_unter == y_ober:
        return 0.0  # Nichts zu integrieren

    # Punktesammlung für Darstellung
    x_treffer, y_treffer = [], []
    x_verfehlt, y_verfehlt = [], []

    netto_treffer = 0

    for _ in range(n_punkte):
        x_rand = np.random.uniform(a, b)
        y_rand = np.random.uniform(y_unter, y_ober)

        try:
            y_func = func(x_rand)
            if not np.isfinite(y_func):
                continue
        except:
            continue

        # Bestimme Vorzeichenbeziehung
        if y_rand >= 0 and 0 <= y_rand <= y_func:
            netto_treffer += 1
            x_treffer.append(x_rand)
            y_treffer.append(y_rand)
        elif y_rand < 0 and y_func <= y_rand <= 0:
            netto_treffer -= 1
            x_treffer.append(x_rand)
            y_treffer.append(y_rand)
        else:
            x_verfehlt.append(x_rand)
            y_verfehlt.append(y_rand)

    rechteck_flaeche = (b - a) * (y_ober - y_unter)
    integral = rechteck_flaeche * (netto_treffer / n_punkte)

    if zeige_plot:
        plt.figure(figsize=(8, 5))
        xs = np.linspace(a, b, 500)
        ys = np.array([func(x) for x in xs])
        plt.plot(xs, ys, label='f(x)', color='black')
        plt.axhline(0, color='gray', linestyle='--')
        plt.scatter(x_treffer, y_treffer, s=1, color='green', label='Treffer')
        plt.scatter(x_verfehlt, y_verfehlt, s=1, color='red', label='Verfehlt')
        plt.title(f"Numerische Integration mittels Monte-Carlo\n"
                  f"Ergebnis bei n={n_punkte} | ≈ {integral:.5f}")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.legend()
        plt.grid(True)
        plt.show()

    return integral

# Hilfsfunktion zur automatischen Extremwertbestimmung
def find_extrema(func, a, b, n=1000):
    xs = np.linspace(a, b, n)
    try:
        ys = func(xs)
        ys = np.where(np.isfinite(ys), ys, np.nan)
    except:
        ys = np.array([func(x) if np.isfinite(func(x)) else np.nan for x in xs])
    return np.nanmin(ys), np.nanmax(ys)

# %%
# Beispiele
def f(x):
    return np.sin(x)

wert = monte_carlo_integration(f, a=0, b=2*np.pi, n_punkte=10000, zeige_plot=True, explorativ=False, y_unter=-0.1, y_ober=0.5)
print("Monte-Carlo-Ergebnis:", wert)
wert = monte_carlo_integration(f, a=0, b=2*np.pi, n_punkte=10000, zeige_plot=True, explorativ=True)
print("Monte-Carlo-Ergebnis:", wert)
# Out:
# Monte-Carlo-Ergebnis: 1.007697259565462
# Monte-Carlo-Ergebnis: -0.027645981176376608

# %% [markdown]
# # Kapitel 3: Visualisierung der Ergebnisse

# %% [markdown]
# # Kapitel 4: Testfälle und Evaluation

# %%
from typing import Callable, List, Tuple
import math
import matplotlib.pyplot as plt
import numpy as np

def auswertung_durchfuehren(
    nutze_feste_grenzen: bool,
    feste_a: float,
    feste_b: float,
    moFaktor: int,
    max_n: int,
    testfunktionen: List[Tuple[str, Callable[[float], float], float, float, Callable[[float], float]]],
):
    farben = {
        "Untersumme": "#f94144",
        "Obersumme": "#f3722c",
        "Trapezregel": "#90be6d",
        "Exakt": "#577590",
        "Montecarlo": "#277da1"
    }

    fehlgeschlagene_funktionen = []

    for name, f, a, b, F in testfunktionen:
        a_aktuell, b_aktuell = (feste_a, feste_b) if nutze_feste_grenzen else (a, b)
        Ns = list(range(1, max_n+1))
        untersummen, obersummen, trapezwerte, montecarlo = [], [], [], []
        funktion_ist_gefailt = False
        fehler_begruendung = ""

        try:
            exaktwert = None if F is None else F(b_aktuell) - F(a_aktuell)
        except Exception as e:
            exaktwert = None
            funktion_ist_gefailt = True
            fehler_begruendung = f"Fehler bei exakter Berechnung: {e}"

        for n in Ns:
            zeige_plot = (n == 20)
            #zeige_plot = False

            try:
                us = numerische_integration(f, a_aktuell, b_aktuell, n, "Untersumme", zeige_plot=zeige_plot)
            except Exception as e:
                us = None
                funktion_ist_gefailt = True
                if not fehler_begruendung:
                    fehler_begruendung = f"Fehler bei Untersumme (n={n}): {e}"

            try:
                os = numerische_integration(f, a_aktuell, b_aktuell, n, "Obersumme", zeige_plot=zeige_plot)
            except Exception as e:
                os = None
                funktion_ist_gefailt = True
                if not fehler_begruendung:
                    fehler_begruendung = f"Fehler bei Obersumme (n={n}): {e}"

            try:
                tr = numerische_integration(f, a_aktuell, b_aktuell, n, "Trapezregel", zeige_plot=zeige_plot)
            except Exception as e:
                tr = None
                funktion_ist_gefailt = True
                if not fehler_begruendung:
                    fehler_begruendung = f"Fehler bei Trapezregel (n={n}): {e}"

            try:
                mo = monte_carlo_integration(f, a_aktuell, b_aktuell, n_punkte=n * moFaktor, zeige_plot=zeige_plot, explorativ=True)
            except Exception as e:
                mo = None
                funktion_ist_gefailt = True
                if not fehler_begruendung:
                    fehler_begruendung = f"Fehler bei Monte-Carlo (n={n}): {e}"

            untersummen.append(us)
            obersummen.append(os)
            trapezwerte.append(tr)
            montecarlo.append(mo)

        mindestens_ein_wert = any(v is not None for v in untersummen + obersummen + trapezwerte + montecarlo)
        if not mindestens_ein_wert:
            fehlgeschlagene_funktionen.append((name, fehler_begruendung or "Alle Methoden fehlgeschlagen."))
            continue

        # Zeichne Vergleichsgraph
        plt.figure(figsize=(9, 5))

        def safe_plot(x, y, label, color):
            y_valid = [v if v is not None else np.nan for v in y]
            plt.plot(x, y_valid, label=label, color=color)

        safe_plot(Ns, untersummen, "Untersumme", farben["Untersumme"])
        safe_plot(Ns, obersummen, "Obersumme", farben["Obersumme"])
        safe_plot(Ns, trapezwerte, "Trapezregel", farben["Trapezregel"])
        safe_plot(Ns, montecarlo, f"Monte-Carlo [n*{moFaktor}]", farben["Montecarlo"])

        if exaktwert is not None:
            plt.hlines(exaktwert, min(Ns), max(Ns), label="Exakter Wert", color=farben["Exakt"], linestyle="dashed")

        plt.title(f"{name} auf [{a_aktuell}, {b_aktuell}]")
        plt.xlabel("Anzahl Teilintervalle (n)")
        plt.ylabel("Flächeninhalt")
        plt.legend()
        plt.grid(True, linestyle="--", alpha=0.5)

        y_werte = [v for v in untersummen + obersummen + trapezwerte + montecarlo if isinstance(v, (int, float)) and not np.isnan(v)]
        if y_werte:
            y_min, y_max = min(y_werte), max(y_werte)
            plt.ylim(y_min - 0.1 * abs(y_max), y_max + 0.1 * abs(y_max))

        if exaktwert is not None:
            plt.text(max(Ns), exaktwert, f"{exaktwert:.5f}", color=farben["Exakt"],
                     fontsize=10, ha="right", va="bottom",
                     bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray'))

        plt.tight_layout()
        plt.show()

    # Fehlermeldungen
    if fehlgeschlagene_funktionen:
        print("\nFehlgeschlagene Funktionen:")
        for name, grund in fehlgeschlagene_funktionen:
            print(f"– {name}: {grund}")
    else:
        print("\nAlle Funktionen erfolgreich geplottet.")

# %%
# Testfunktionen mit Stammfunktion
testfunktionen = [
    # Edge Cases & Spezielle Funktionen
    ("f(x) = -x²", lambda x: -x**2, -2, 2, lambda x: -(1/3) * x**3),
    ("f(x) = 1/(x - 1)", lambda x: 1 / (x - 1), 0.5, 1.5, None),
    ("f(x) = 1/x", lambda x: 1/x, 1, 2, lambda x: math.log(x)),
    ("f(x) = 1/√x", lambda x: 1 / math.sqrt(x), 0.0001, 1, lambda x: 2 * math.sqrt(x)),
    ("f(x) = 2x + 1", lambda x: 2 * x + 1, 0, 1, lambda x: x**2 + x),
    ("f(x) = 5", lambda x: 5, 2, 6, lambda x: 5 * x),
    ("f(x) = cos(x)", math.cos, 0, math.pi, lambda x: math.sin(x)),
    ("f(x) = cos²(x)", lambda x: math.cos(x)**2, 0, math.pi, lambda x: (x / 2) + (math.sin(2 * x) / 4)),
    ("f(x) = eˣ", math.exp, 0, 1, lambda x: math.exp(x)),
    ("f(x) = eˣ (erweitert)", math.exp, 0, 10, lambda x: math.exp(x)),
    ("f(x) = erf(x)", math.erf, -2, 2, None),
    ("f(x) = ln(x)", math.log, 1, 2, lambda x: x * math.log(x) - x),
    ("f(x) = ln(x - 2)", lambda x: math.log(x - 2), 3, 4, lambda x: (x - 2) * math.log(x - 2) - (x - 2)),
    ("f(x) = ln(x) auf großem Intervall", math.log, 1, 1000, lambda x: x * math.log(x) - x),
    ("f(x) = sin(x)", math.sin, 0, math.pi, lambda x: -math.cos(x)),
    ("f(x) = sin(x) (vollständig)", math.sin, 0, 2 * math.pi, lambda x: -math.cos(x)),
    ("f(x) = sin²(x)", lambda x: math.sin(x)**2, 0, math.pi, lambda x: (x / 2) - (math.sin(2 * x) / 4)),
    ("f(x) = sin((x + 1) * 16π)", lambda x: math.sin((x + 1) * 16 * math.pi), 0, 1, 
     lambda x: -1 / (16 * math.pi) * math.cos((x + 1) * 16 * math.pi)),
    ("f(x) = sin(100x)", lambda x: math.sin(100 * x), 0, math.pi, lambda x: -math.cos(100 * x) / 100),
    ("f(x) = x²", lambda x: x**2, 0, 3, lambda x: (1/3) * x**3),
    ("f(x) = x² - 4x + 2", lambda x: x**2 - 4*x + 2, -3, 3, lambda x: (1/3)*x**3 - 2*x**2 + 2*x),
    ("f(x) = x³ - x", lambda x: x**3 - x, -1, 1, lambda x: (1/4)*x**4 - (1/2)*x**2),
    ("f(x) = x·sin(x)", lambda x: x * math.sin(x), 0, 2 * math.pi, lambda x: -x * math.cos(x) + math.sin(x)),
    ("f(x) = √x", math.sqrt, 0, 4, lambda x: (2/3) * x**(3/2)),
    ("f(x) = |x|", abs, -1, 1, lambda x: 0.5 * x**2 if x >= 0 else -0.5 * x**2),
    ("f(x) = (2/√π)·e^(-x²)", lambda x: (2 / math.sqrt(math.pi)) * math.exp(-x**2), -2, 2, lambda x: math.erf(x)),
    ("Sprung: 1 (<0), 2 (≥0)", lambda x: 1 if x < 0 else 2, -1, 1, None),
]

# %%
auswertung_durchfuehren(
    nutze_feste_grenzen=False,
    feste_a=-5,
    feste_b=5,
    moFaktor=10,
    max_n=100,
    testfunktionen=testfunktionen,
)

# %% [markdown]
# # Kapitel 5: Grenzen numerischer Integration

# %%
# Testfunktionen mit Stammfunktion
hochOsizilierendeFunktionTest = [
    (
        "f(x) = sin((x + 1) * 16π)",
        lambda x: math.sin((x + 1) * 16 * math.pi),
        0,
        1,
        lambda x: -1 / (16 * math.pi) * math.cos((x + 1) * 16 * math.pi)
    ),
]

# %%
auswertung_durchfuehren(
    nutze_feste_grenzen=False,
    feste_a=-5,
    feste_b=5,
    moFaktor=1,
    max_n=200,
    testfunktionen=hochOsizilierendeFunktionTest,
)
# Out:
# Alle Funktionen erfolgreich geplottet.

# %% [markdown]
# ## 1. **Theoretischer Hintergrund**
#
# ### Exakter Wert des Integrals
#
# Die Funktion kann analytisch integriert werden:
# \[
# F(x) = \int \sin((x+1) \cdot 16\pi) \, dx
# \]
# Setze \( u = (x+1) \cdot 16\pi \Rightarrow du = 16\pi \, dx \Rightarrow dx = \frac{1}{16\pi} du \)
#
# \[
# \Rightarrow F(x) = \frac{1}{16\pi} \int \sin(u) \, du = -\frac{1}{16\pi} \cos((x+1)\cdot 16\pi) + C
# \]
#
# Das bestimmte Integral auf \([0,1]\):
# \[
# \int_0^1 \sin((x+1)\cdot16\pi) \, dx = -\frac{1}{16\pi} \left[ \cos(2\cdot16\pi) - \cos(1\cdot16\pi) \right]
# \]
# Da \(\cos(2\cdot16\pi) = \cos(1\cdot16\pi) = 1\), ergibt sich:
# \[
# \boxed{I = 0}
# \]

# %% [markdown]
# # Kapitel 6: Fakultativ: Gaußsche Fehlerfunktion

# %% [markdown]
# # Kapitel 7: Zusammenfassung und Fazit

# %% [markdown]
# ## Anhang: Quellen, Anmerkungen, Gruppenmitglieder
